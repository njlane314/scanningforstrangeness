# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from src.config import Config
from src.dataset import Dataset
from src.visualiser import Visualiser

import importlib
import src.visualiser as visualiser_module
importlib.reload(visualiser_module)
from src.visualiser import Visualiser

pth = "cfg/default.yaml"
cfg = Config(pth)

print(cfg.as_dict())
print(dir(Visualiser))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {'dataset': {'path': '/gluster/data/dune/niclane/', 'file': 'nlane_prod_strange_resample_fhc_run2_fhc_reco2_reco2_trainingimage_signal_lambdamuon_1000_ana.root', 'tree': 'imageanalyser/ImageTree', 'width': 512, 'height': 512, 'planes': ['U', 'V', 'W'], 'induction_plane': 2}, 'train': {'num_epochs': 1, 'batch_size': 8, 'learning_rate': 0.001, 'checkpoint_directory': './chk', 'input_channels': 3, 'numer_classes': 6, 'segmentation_classes': 5, 'filters': 32, 'dropout': 0.1, 'feature_dimensions': 128, 'optimiser': 'Adam', 'weight_decay': 0.0001}}
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_get_random', 'visualise_input_event', 'visualise_overlay_event', 'visualise_truth_event']

# %%
ds = Dataset(cfg)
vis = Visualiser(cfg)

# %%
vis.visualise_overlay_event(ds)
vis.visualise_overlay_event(ds)
vis.visualise_overlay_event(ds)
vis.visualise_overlay_event(ds)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /gluster/home/niclane/scanningforstrangeness/visualise.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell://tunnel%2Bnoether/gluster/home/niclane/scanningforstrangeness/visualise.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> vis.visualise_overlay_event(ds)
#       <a href='vscode-notebook-cell://tunnel%2Bnoether/gluster/home/niclane/scanningforstrangeness/visualise.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> vis.visualise_overlay_event(ds)
#       <a href='vscode-notebook-cell://tunnel%2Bnoether/gluster/home/niclane/scanningforstrangeness/visualise.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> vis.visualise_overlay_event(ds)
#
# File ~/scanningforstrangeness/src/visualiser.py:74, in Visualiser.visualise_overlay_event(self, dataset)
#      73 def visualise_overlay_event(self, dataset):
# ---> 74     idx = self._get_random(dataset)
#      75     event_data = dataset[idx]
#      76     input_img, truth_img, r, sr, evnum = event_data
#
# File ~/scanningforstrangeness/src/visualiser.py:17, in Visualiser._get_random(self, dataset)
#      16 def _get_random(self, dataset):
# ---> 17     sig = [i for i, t in enumerate(dataset.type) if t == 0]
#      18     if not sig:
#      19         return random.choice(dataset)
#
# AttributeError: 'Dataset' object has no attribute 'type'
